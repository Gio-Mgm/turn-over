# %%
import sys
sys.path.append("../src")
import pandas as pd
import numpy as np
from tensorflow.keras import Sequential, layers, callbacks
from sklearn.model_selection import train_test_split
from functions import get_df_uniques

# %%
df = pd.read_csv("../data/01_raw/attrition_train.csv")

# %%
df["Attrition"] = df["Attrition"].apply(lambda x: 0 if x == "No" else 1)
y = df["Attrition"]
X = df.drop('Attrition', axis=1)
X = pd.get_dummies(X)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 55 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                1100 non-null   int64
#  1   DailyRate                          1100 non-null   int64
#  2   DistanceFromHome                   1100 non-null   int64
#  3   Education                          1100 non-null   int64
#  4   EmployeeCount                      1100 non-null   int64
#  5   EmployeeNumber                     1100 non-null   int64
#  6   EnvironmentSatisfaction            1100 non-null   int64
#  7   HourlyRate                         1100 non-null   int64
#  8   JobInvolvement                     1100 non-null   int64
#  9   JobLevel                           1100 non-null   int64
#  10  JobSatisfaction                    1100 non-null   int64
#  11  MonthlyIncome                      1100 non-null   int64
#  12  MonthlyRate                        1100 non-null   int64
#  13  NumCompaniesWorked                 1100 non-null   int64
#  14  PercentSalaryHike                  1100 non-null   int64
#  15  PerformanceRating                  1100 non-null   int64
#  16  RelationshipSatisfaction           1100 non-null   int64
#  17  StandardHours                      1100 non-null   int64
#  18  StockOptionLevel                   1100 non-null   int64
#  19  TotalWorkingYears                  1100 non-null   int64
#  20  TrainingTimesLastYear              1100 non-null   int64
#  21  WorkLifeBalance                    1100 non-null   int64
#  22  YearsAtCompany                     1100 non-null   int64
#  23  YearsInCurrentRole                 1100 non-null   int64
#  24  YearsSinceLastPromotion            1100 non-null   int64
#  25  YearsWithCurrManager               1100 non-null   int64
#  26  BusinessTravel_Non-Travel          1100 non-null   uint8
#  27  BusinessTravel_Travel_Frequently   1100 non-null   uint8
#  28  BusinessTravel_Travel_Rarely       1100 non-null   uint8
#  29  Department_Human Resources         1100 non-null   uint8
#  30  Department_Research & Development  1100 non-null   uint8
#  31  Department_Sales                   1100 non-null   uint8
#  32  EducationField_Human Resources     1100 non-null   uint8
#  33  EducationField_Life Sciences       1100 non-null   uint8
#  34  EducationField_Marketing           1100 non-null   uint8
#  35  EducationField_Medical             1100 non-null   uint8
#  36  EducationField_Other               1100 non-null   uint8
#  37  EducationField_Technical Degree    1100 non-null   uint8
#  38  Gender_Female                      1100 non-null   uint8
#  39  Gender_Male                        1100 non-null   uint8
#  40  JobRole_Healthcare Representative  1100 non-null   uint8
#  41  JobRole_Human Resources            1100 non-null   uint8
#  42  JobRole_Laboratory Technician      1100 non-null   uint8
#  43  JobRole_Manager                    1100 non-null   uint8
#  44  JobRole_Manufacturing Director     1100 non-null   uint8
#  45  JobRole_Research Director          1100 non-null   uint8
#  46  JobRole_Research Scientist         1100 non-null   uint8
#  47  JobRole_Sales Executive            1100 non-null   uint8
#  48  JobRole_Sales Representative       1100 non-null   uint8
#  49  MaritalStatus_Divorced             1100 non-null   uint8
#  50  MaritalStatus_Married              1100 non-null   uint8
#  51  MaritalStatus_Single               1100 non-null   uint8
#  52  Over18_Y                           1100 non-null   uint8
#  53  OverTime_No                        1100 non-null   uint8
#  54  OverTime_Yes                       1100 non-null   uint8
# dtypes: int64(26), uint8(29)
# memory usage: 254.7 KB

# %%
#X=X[num_cols]
#X=np.asarray(X).astype('float32')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.15, random_state=1)

# %%
# model
model = Sequential([
    layers.Dense(32, activation="relu", input_shape=[X.shape[1]]),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(16, activation="relu"),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(8, activation="relu"),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(1, activation="sigmoid")
])

# %%
model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["binary_accuracy"]
)

# %%
early_stopping = callbacks.EarlyStopping(
    patience=10,
    min_delta=0.001,
    restore_best_weights=True,
)

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    batch_size=512,
    epochs=1000,
    callbacks=[early_stopping],
    verbose=0, # hide the output because we have so many epochs
)

# %%
history_df = pd.DataFrame(history.history)
# Start the plot at epoch 5
#history_df.loc[5:, ['loss', 'val_loss']].plot()
#.history_df.loc[5:, ['binary_accuracy', 'val_binary_accuracy']].plot()

print(("Best Validation Loss: {:0.4f}" +\
      "\nBest Validation Accuracy: {:0.4f}")\
      .format(history_df['val_loss'].min(), 
              history_df['val_binary_accuracy'].max()))
# Out:
# Best Validation Loss: 0.4488
# Best Validation Accuracy: 0.8424

# %%
import tensorflow as tf
import autokeras as ak
import kerastuner as kt

METRICS = [
      tf.keras.metrics.AUC(name='auc'),
]

# Initialize the structured data classifier.
clf = ak.StructuredDataClassifier(
    overwrite=True,
    max_trials=4,
    metrics=METRICS,
    objective = kt.Objective("auc", direction="max"),
    loss="binary_crossentropy"
)

early_stopping = callbacks.EarlyStopping(
    min_delta=0.001,  # minimium amount of change to count as an improvement
    patience=5,  # how many epochs to wait before stopping
    restore_best_weights=True,
)

clf.fit(X_train, y_train, epochs=100, callbacks=[early_stopping])
# Out:
# Trial 4 Complete [00h 00m 06s]
# auc: 0.9754437804222107
#
# Best auc So Far: 0.9754437804222107
# Total elapsed time: 00h 00m 31s
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/100
# 30/30 [==============================] - 1s 2ms/step - loss: 0.6153 - auc: 0.5906
# Epoch 2/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3540 - auc: 0.7977
# Epoch 3/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3086 - auc: 0.8556
# Epoch 4/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2798 - auc: 0.8794
# Epoch 5/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2560 - auc: 0.8975
# Epoch 6/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2362 - auc: 0.9141
# Epoch 7/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2178 - auc: 0.9267
# Epoch 8/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2010 - auc: 0.9381
# Epoch 9/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1844 - auc: 0.9501
# Epoch 10/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1688 - auc: 0.9599
# Epoch 11/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1532 - auc: 0.9688
# Epoch 12/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1379 - auc: 0.9757
# Epoch 13/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1236 - auc: 0.9820
# Epoch 14/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1102 - auc: 0.9883
# Epoch 15/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0967 - auc: 0.9922
# Epoch 16/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0847 - auc: 0.9954
# Epoch 17/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0735 - auc: 0.9973
# Epoch 18/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0639 - auc: 0.9983
# Epoch 19/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0549 - auc: 0.9991
# Epoch 20/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0470 - auc: 0.9994
# Epoch 21/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0403 - auc: 0.9996
# Epoch 22/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0344 - auc: 0.9998
# Epoch 23/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0295 - auc: 0.9999
# Epoch 24/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0253 - auc: 0.9999
# Epoch 25/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0217 - auc: 1.0000
# Epoch 26/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0186 - auc: 1.0000
# Epoch 27/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0161 - auc: 1.0000
# Epoch 28/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0139 - auc: 1.0000
# Epoch 29/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0121 - auc: 1.0000
# Epoch 30/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0106 - auc: 1.0000
# Epoch 31/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0093 - auc: 1.0000
# Epoch 32/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0082 - auc: 1.0000
# Epoch 33/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0073 - auc: 1.0000
# Epoch 34/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0065 - auc: 1.0000
# Epoch 35/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0059 - auc: 1.0000
# Epoch 36/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0053 - auc: 1.0000
# Epoch 37/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0048 - auc: 1.0000
# Epoch 38/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0044 - auc: 1.0000
# Epoch 39/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0040 - auc: 1.0000
# Epoch 40/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0036 - auc: 1.0000
# Epoch 41/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0033 - auc: 1.0000
# Epoch 42/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0031 - auc: 1.0000
# Epoch 43/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0028 - auc: 1.0000
# Epoch 44/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0026 - auc: 1.0000
# Epoch 45/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0024 - auc: 1.0000
# Epoch 46/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0023 - auc: 1.0000
# Epoch 47/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0021 - auc: 1.0000
# Epoch 48/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0020 - auc: 1.0000
# Epoch 49/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0018 - auc: 1.0000
# Epoch 50/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0017 - auc: 1.0000
# Epoch 51/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0016 - auc: 1.0000
# Epoch 52/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0015 - auc: 1.0000
# Epoch 53/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0014 - auc: 1.0000
# Epoch 54/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0014 - auc: 1.0000
# Epoch 55/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0013 - auc: 1.0000
# Epoch 56/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0012 - auc: 1.0000
# Epoch 57/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0011 - auc: 1.0000
# Epoch 58/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0011 - auc: 1.0000
# Epoch 59/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0010 - auc: 1.0000
# Epoch 60/100
# 30/30 [==============================] - 0s 2ms/step - loss: 9.8402e-04 - auc: 1.0000
# Epoch 61/100
# 30/30 [==============================] - 0s 2ms/step - loss: 9.3668e-04 - auc: 1.0000
# Epoch 62/100
# 30/30 [==============================] - 0s 2ms/step - loss: 8.9152e-04 - auc: 1.0000
# Epoch 63/100
# 30/30 [==============================] - 0s 2ms/step - loss: 8.4876e-04 - auc: 1.0000
# Epoch 64/100
# 30/30 [==============================] - 0s 2ms/step - loss: 8.0838e-04 - auc: 1.0000
# Epoch 65/100
# 30/30 [==============================] - 0s 2ms/step - loss: 7.7221e-04 - auc: 1.0000
# Epoch 66/100
# 30/30 [==============================] - 0s 3ms/step - loss: 7.3507e-04 - auc: 1.0000
# Epoch 67/100
# 30/30 [==============================] - 0s 2ms/step - loss: 7.0249e-04 - auc: 1.0000
# Epoch 68/100
# 30/30 [==============================] - 0s 2ms/step - loss: 6.7108e-04 - auc: 1.0000
# Epoch 69/100
# 30/30 [==============================] - 0s 2ms/step - loss: 6.4268e-04 - auc: 1.0000
# Epoch 70/100
# 30/30 [==============================] - 0s 2ms/step - loss: 6.1389e-04 - auc: 1.0000
# Epoch 71/100
# 30/30 [==============================] - 0s 2ms/step - loss: 5.8865e-04 - auc: 1.0000
# Epoch 72/100
# 30/30 [==============================] - 0s 2ms/step - loss: 5.6371e-04 - auc: 1.0000
# Epoch 73/100
# 30/30 [==============================] - 0s 2ms/step - loss: 5.4018e-04 - auc: 1.0000
# Epoch 74/100
# 30/30 [==============================] - 0s 2ms/step - loss: 5.1886e-04 - auc: 1.0000
# Epoch 75/100
# 30/30 [==============================] - 0s 2ms/step - loss: 4.9780e-04 - auc: 1.0000
# Epoch 76/100
# 30/30 [==============================] - 0s 2ms/step - loss: 4.7820e-04 - auc: 1.0000
# Epoch 77/100
# 30/30 [==============================] - 0s 2ms/step - loss: 4.5958e-04 - auc: 1.0000
# Epoch 78/100
# 30/30 [==============================] - 0s 2ms/step - loss: 4.4190e-04 - auc: 1.0000
# Epoch 79/100
# 30/30 [==============================] - 0s 2ms/step - loss: 4.2510e-04 - auc: 1.0000
# Epoch 80/100
# 30/30 [==============================] - 0s 2ms/step - loss: 4.0882e-04 - auc: 1.0000
# Epoch 81/100
# 30/30 [==============================] - 0s 2ms/step - loss: 3.9394e-04 - auc: 1.0000
# Epoch 82/100
# 30/30 [==============================] - 0s 2ms/step - loss: 3.7937e-04 - auc: 1.0000
# Epoch 83/100
# 30/30 [==============================] - 0s 2ms/step - loss: 3.6561e-04 - auc: 1.0000
# Epoch 84/100
# 30/30 [==============================] - 0s 2ms/step - loss: 3.5251e-04 - auc: 1.0000
# Epoch 85/100
# 30/30 [==============================] - 0s 2ms/step - loss: 3.4000e-04 - auc: 1.0000
# Epoch 86/100
# 30/30 [==============================] - 0s 2ms/step - loss: 3.2803e-04 - auc: 1.0000
# Epoch 87/100
# 30/30 [==============================] - 0s 2ms/step - loss: 3.1684e-04 - auc: 1.0000
# Epoch 88/100
# 30/30 [==============================] - 0s 2ms/step - loss: 3.0572e-04 - auc: 1.0000
# Epoch 89/100
# 30/30 [==============================] - 0s 2ms/step - loss: 2.9514e-04 - auc: 1.0000
# Epoch 90/100
# 30/30 [==============================] - 0s 2ms/step - loss: 2.8541e-04 - auc: 1.0000
# Epoch 91/100
# 30/30 [==============================] - 0s 2ms/step - loss: 2.7589e-04 - auc: 1.0000
# Epoch 92/100
# 30/30 [==============================] - 0s 2ms/step - loss: 2.6689e-04 - auc: 1.0000
# Epoch 93/100
# 30/30 [==============================] - 0s 2ms/step - loss: 2.5821e-04 - auc: 1.0000
# Epoch 94/100
# 30/30 [==============================] - 0s 2ms/step - loss: 2.4987e-04 - auc: 1.0000
# Epoch 95/100
# 30/30 [==============================] - 0s 2ms/step - loss: 2.4186e-04 - auc: 1.0000
# Epoch 96/100
# 30/30 [==============================] - 0s 2ms/step - loss: 2.3425e-04 - auc: 1.0000
# Epoch 97/100
# 30/30 [==============================] - 0s 2ms/step - loss: 2.2687e-04 - auc: 1.0000
# Epoch 98/100
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1983e-04 - auc: 1.0000
# Epoch 99/100
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1300e-04 - auc: 1.0000
# Epoch 100/100
# 30/30 [==============================] - 0s 2ms/step - loss: 2.0650e-04 - auc: 1.0000
# INFO:tensorflow:Assets written to: ./structured_data_classifier/best_model/assets

# %%
from tensorflow.keras.models import load_model

model = clf.export_model()
try:
    model.save("model_autokeras", save_format="tf")
except Exception:
    model.save("model_autokeras.h5")


loaded_model = load_model("model_autokeras", custom_objects=ak.CUSTOM_OBJECTS)

predicted_y = loaded_model.predict(tf.expand_dims(X_test, -1))
print(predicted_y)
# Out:
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571aac5e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f45720d41f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571d79a60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571c50f70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571aa5c10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571a4a0d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571c50ee0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571d66310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571ab9790> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571a4aa60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571aac8b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571c50670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571a4a700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571a58820> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571c508b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571ab99d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f45720d4310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571a5f670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571ab9820> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571c50af0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571a58700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571a69040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571a5f940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571c50c10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571a4ae50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571a69dc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571a4a430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571a5f550> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571a583a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571aa5700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571a7a0d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571aac9d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571a69940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571ab9670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571a7a9d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571a5f040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571aac160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571a7a940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571a0a790> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571aac3a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571a5fdc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571a4a8b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571a125e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571d66790> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f45720d4280> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571a0a700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571a12f70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571a128b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571aacee0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f4571a7ad30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# INFO:tensorflow:Assets written to: model_autokeras/assets
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f45b2bf49d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f45b2e5eaf0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f45b16bd040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f45b2e5e3a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f45b30cf9d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f45b2b20940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f45b16bddc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f45b3bd9790> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f45b2ad1820> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f45b2e5e550> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f45b1f7f430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f45735464c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f45b16bd550> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f45b3157c10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f45b1caf430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f45735e2040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f45b1dcff70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f45735a9c10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f45735c2040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f457361fa60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f457350d670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f45b3bd9310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f45735c2af0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f45b1756ee0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f457356b040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f45735a9040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f457361fdc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f45b17561f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f457365e430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f45735a9160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f45735e2280> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f45b1643040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [[3.48864475e-08]
#  [5.02288913e-07]
#  [9.99989033e-01]
#  [4.82866675e-01]
#  [3.31542611e-01]
#  [9.63446498e-03]
#  [6.04416637e-05]
#  [6.26234942e-06]
#  [5.75248027e-09]
#  [1.81975290e-09]
#  [2.82379442e-05]
#  [8.85634303e-01]
#  [8.14185478e-06]
#  [8.71605217e-01]
#  [4.61965410e-10]
#  [2.61913836e-02]
#  [3.12036276e-03]
#  [8.85003737e-06]
#  [1.89101696e-03]
#  [3.78738985e-10]
#  [5.91257958e-08]
#  [1.73652734e-06]
#  [1.19587821e-11]
#  [6.54251380e-06]
#  [1.31815672e-04]
#  [3.59346275e-10]
#  [9.99973893e-01]
#  [1.90590470e-07]
#  [4.72685695e-03]
#  [2.72847495e-10]
#  [1.08929797e-07]
#  [9.99971926e-01]
#  [5.43156148e-07]
#  [1.42260701e-08]
#  [1.27968192e-02]
#  [2.95919253e-05]
#  [3.33363452e-08]
#  [3.10531014e-08]
#  [2.31314488e-07]
#  [3.12149525e-04]
#  [4.45288420e-03]
#  [7.89350807e-10]
#  [2.23627687e-03]
#  [3.57899116e-05]
#  [4.98205423e-04]
#  [1.56383378e-10]
#  [9.55641270e-02]
#  [1.10874258e-04]
#  [1.39197473e-10]
#  [5.74597716e-03]
#  [5.05179167e-04]
#  [1.65495135e-06]
#  [1.01917380e-04]
#  [2.93959135e-10]
#  [1.21505593e-07]
#  [2.23674051e-05]
#  [2.81397104e-02]
#  [2.34854663e-10]
#  [1.98894739e-03]
#  [5.76738053e-08]
#  [3.44775117e-06]
#  [5.55957467e-06]
#  [3.54309648e-08]
#  [1.88830197e-02]
#  [2.65411071e-09]
#  [5.45956731e-01]
#  [1.92407806e-05]
#  [3.82327635e-05]
#  [1.45725262e-05]
#  [5.81711531e-04]
#  [2.34223130e-09]
#  [2.13364206e-06]
#  [1.36194527e-02]
#  [2.89332911e-05]
#  [2.23375719e-06]
#  [1.99817237e-06]
#  [3.82499911e-06]
#  [9.99824762e-01]
#  [9.99921083e-01]
#  [2.72849867e-08]
#  [6.13698603e-06]
#  [2.15839245e-05]
#  [4.39464152e-02]
#  [4.19595881e-06]
#  [4.91611036e-06]
#  [5.45300245e-05]
#  [9.99587893e-01]
#  [1.39634981e-09]
#  [2.11776605e-05]
#  [1.00000000e+00]
#  [4.32174638e-05]
#  [3.78298466e-07]
#  [9.88165266e-06]
#  [2.97468901e-03]
#  [8.91602039e-03]
#  [9.98388816e-10]
#  [2.18915204e-07]
#  [3.24755907e-03]
#  [4.26232815e-03]
#  [6.79772794e-10]
#  [6.39131557e-08]
#  [2.51945087e-09]
#  [1.43408775e-02]
#  [9.45231795e-01]
#  [3.82898450e-02]
#  [4.87118959e-03]
#  [6.46193585e-05]
#  [5.29108365e-06]
#  [1.40982568e-02]
#  [1.31633096e-05]
#  [4.81254148e-09]
#  [8.79879813e-09]
#  [4.15188968e-02]
#  [9.99995291e-01]
#  [6.78474635e-07]
#  [4.81062585e-08]
#  [1.22668862e-05]
#  [5.59768677e-02]
#  [1.17124422e-04]
#  [9.78435814e-01]
#  [4.09364700e-04]
#  [6.05055690e-03]
#  [9.41208899e-02]
#  [1.24633312e-04]
#  [4.91525682e-08]
#  [2.34813378e-05]
#  [9.99793649e-01]
#  [4.12493944e-04]
#  [9.05601727e-09]
#  [1.19492597e-06]
#  [2.78085470e-04]
#  [2.50203609e-02]
#  [2.82505155e-03]
#  [3.33987806e-08]
#  [2.01498242e-05]
#  [9.33482891e-09]
#  [6.32035732e-03]
#  [4.04955447e-01]
#  [7.36752152e-03]
#  [3.72013369e-06]
#  [6.48696732e-05]
#  [3.93782739e-06]
#  [2.58591815e-08]
#  [1.67222982e-08]
#  [1.09141820e-05]
#  [5.27336113e-08]
#  [7.69972801e-04]
#  [2.86749661e-01]
#  [8.41866970e-01]
#  [7.42734313e-01]
#  [2.47569084e-02]
#  [9.32842231e-05]
#  [2.55031943e-01]
#  [1.10061272e-04]
#  [1.81198120e-04]
#  [1.59342418e-11]
#  [9.86170292e-01]
#  [1.79499388e-04]
#  [1.45460344e-05]
#  [6.37261244e-10]
#  [2.04649568e-03]
#  [2.56711115e-08]
#  [1.74187142e-06]
#  [9.95550275e-01]
#  [1.46803347e-09]]
